# %% [markdown]
# <a href="https://colab.research.google.com/github/cogitovsmachina/python_emailer/blob/main/Simple_python_emailer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib
import pandas as pd
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from google.colab import drive


drive.mount('/content/drive')

# Load your data
file_path = '/mnt/data/subscribed_email_audience_export_a1bf9259dc.csv'
url_test_path = '/content/TESTING_CDMX_Only_Email_Audience_Export.csv'
url_path = 'https://raw.githubusercontent.com/cogitovsmachina/python_emailer/refs/heads/main/TESTING_CDMX%20Only%20Email%20Audience%20Export.csv'

data = pd.read_csv(url_test_path)
#data = pd.read_csv(url_path)

data_pandas = pd.DataFrame(data)
# IPython.display allows "pretty printing" of dataframes
# in the Jupyter notebook
display(data_pandas)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          Email Address
# 0  nrikediaz@gmail.com

# %%
from google.colab import userdata

# Set up your email credentials using keys from Colab
email_address = userdata.get('devf_email_address')
email_password = userdata.get('devf_email_password')
#carbon_copy_emails = userdata.get('email_cc')


smtp_server = "smtp.gmail.com"
smtp_port = 587

# Start the SMTP server connection
with smtplib.SMTP(smtp_server, smtp_port) as server:
    server.starttls()
    server.login(email_address, email_password)

    for index, row in data.iterrows():
        # Customize message with user data
        msg = MIMEMultipart()
        msg["From"] = email_address
        msg["To"] = row["Email Address"]
        msg["CC"] = carbon_copy_emails
        msg["Subject"] = "Te invitamos al re-lanzamiento del Google Developer Group CDMX"

        # Message body
        message = """¡Hola a todas y todos!

Te invitamos al re-lanzamiento del GDG CDMX en Google México 🎉, contaremos con un par de charlas técnicas así como espacio para conocer y conectar con algunos Googlers interesados en contratar talento técnico para la oficina regional.

🗓 Fecha: Miércoles, 13 de noviembre de 2024
🕙 Hora: 5:30 PM – 8:00 PM
📍 Lugar: Calle Montes Urales 445, Lomas - Virreyes, Lomas de Chapultepec, Miguel Hidalgo, 11000 Ciudad de México, CDMX.

¡Nos encantaría verte ahí! 😎

Para más información y confirmar tu asistencia, visita este enlace:
https://rsvp.withgoogle.com/events/google-connect-talk-with-paco-eduardo_26e640
"""


        msg.attach(MIMEText(message, "plain"))


        # Send the email
        server.sendmail(email_address, row["Email Address"], msg.as_string())
        print(f"Sent email to {row['Email Address']}")

print("All emails sent!")
# Out:
# Sent email to nrikediaz@gmail.com
# All emails sent!
